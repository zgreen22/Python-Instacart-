# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
path='/Users/zacharygreen/Desktop/instacart analysis/data'

# %%
df_merge=pd.read_pickle(os.path.join(path, 'prepared data', 'ords_prods_merge_ready.pkl'))

# %%
df_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    days_since_prior_order  add_to_cart_order  reordered  _merge  \
# 0                     3.0                  5          0    both
# ...

# %%
df_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# The mean orders for each department are different. I'm not sure what is specifically different, some averages are higher than others and some are lower.

# %%
df_merge.groupby('loyalty_flag').agg({'prices':['mean']})
# Out:
#                      prices
#                        mean
# loyalty_flag
# Loyal customer    10.386336
# New customer      13.294670
# Regular customer  12.495717

# %% [markdown]
# I could check the min and max but they wouldnt have any relevance on the data, it would just be one variable and they would probably all be the same. Anyways, according to my analysis, loyal customers actually spend the least vs new customers who spend the most on average per item. Regular customers are right in between. If I was at instacart, it would be hard to determine the best method of approach here.

# %%
df_merge['average_price'] = df_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    add_to_cart_order  reordered  _merge    price_range_loc     busiest_day  \
# ...

# %%
df_merge.loc[df_merge['average_price'] < 10, 'spender_flag'] = 'Low Spender'
df_merge.loc[df_merge['average_price'] >=10, 'spender_flag'] = 'High Spender'

# %%
df_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    reordered  _merge    price_range_loc     busiest_day  \
# 0          0    both  Mid-range product  Regularly busy
# ...

# %%
df_merge['spender_flag'].value_counts(dropna=False)
# Out:
# Low Spender     31770614
# High Spender      634245
# Name: spender_flag, dtype: int64

# %%
df_merge['order_frequency'] = df_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.mean)

# %%
df_merge.head()
# Out:
#    Unnamed: 0_x  product_id                product_name  aisle_id  \
# 0             0           1  Chocolate Sandwich Cookies        61
# 1             0           1  Chocolate Sandwich Cookies        61
# 2             0           1  Chocolate Sandwich Cookies        61
# 3             0           1  Chocolate Sandwich Cookies        61
# 4             0           1  Chocolate Sandwich Cookies        61
#
#    department_id  prices  Unnamed: 0_y  order_id  user_id eval_set  ...  \
# 0             19     5.8          1987   3139998      138    prior  ...
# 1             19     5.8          1989   1977647      138    prior  ...
# 2             19     5.8         11433    389851      709    prior  ...
# 3             19     5.8         12198    652770      764    prior  ...
# 4             19     5.8         12200   1813452      764    prior  ...
#
#    _merge    price_range_loc     busiest_day  Busiest_Least_Busiest_days  \
# ...

# %%
df_merge.loc[(df_merge['order_frequency'] > 10) | (df_merge['order_frequency'] <= 20), 'frequency_flag'] = 'Regular customer'

df_merge.loc[df_merge['order_frequency'] <=10, 'frequency_flag'] = 'Frequent customer'

# %%
df_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer    16468582
# Regular customer     15936272
# NaN                         5
# Name: frequency_flag, dtype: int64

# %%
df_merge.loc[df_merge['order_frequency'] > 20, 'frequency_flag'] = 'Non frequent'

# %%
df_merge['frequency_flag'].value_counts(dropna=False)
# Out:
# Frequent customer    16468582
# Regular customer     12521159
# Non frequent          3415113
# NaN                         5
# Name: frequency_flag, dtype: int64
